# %% [markdown]
# ## Hybrid Retrieval and Agent Integration - PoC - 3
# Here, we will send the entire messages from subgraph `scratchpad` back to the parent graph. The goal is for the parent-graph to be able to answer follow-up questions, like --
#
# - Give me the code used to generate your statistics.
# - What methodology did you use to generate your results.
# - Which filters did you apply.
#
# Since the current data-analyst subgraph only reports back with the final answer (and not the intermediate code and steps), the parent graph is unable to answer any follow-up questions like the ones demoe'd above.
#
# Let's get started.

# %%
import os
import io
import sys
import json
import traceback
import regex as re
import pandas as pd
from pyjstat import pyjstat
from textwrap import dedent
from pyjstat import pyjstat
from pydantic import BaseModel, Field
from typing_extensions import TypedDict
from typing import Dict, List, Any, Literal, Annotated

from langgraph.types import Command
from langchain_core.tools import tool
from langgraph.graph.message import add_messages
from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode, tools_condition
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage, AIMessage, ToolMessage
from langgraph.prebuilt import InjectedState
from langchain_core.tools import tool, InjectedToolCallId

# %%
from pathlib import Path
import os

root = Path().absolute().parents[1]
os.chdir(str(root))

from src.helpers.json_stat_archive_db import JSONStatArchiveDB

# %%
llm_low = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-lite",
    temperature=1,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)
llm_med = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=1,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)
llm_high  = ChatGoogleGenerativeAI(
    model="gemini-2.5-pro",
    temperature=1,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
def _run_python_safely(code: str) -> Dict[str, Any]:
    """
    Minimal sandbox runner. In production: isolate with subprocess, container, time & mem limits.
    Returns {"stdout": str, "error": {"type":, "message":, "trace":}} on failure.
    """
    stdout_capture = io.StringIO()
    old_stdout, old_stderr = sys.stdout, sys.stderr
    sys.stdout = stdout_capture
    sys.stderr = stdout_capture  # co-mingle
    globals_dict = {"__name__": "__main__"}
    try:
        exec(code, globals_dict, globals_dict)
        out = stdout_capture.getvalue()
        return {"stdout": out}
    except Exception as e:
        err = {"type": e.__class__.__name__, "message": str(e), "trace": traceback.format_exc()}
        return {"stdout": stdout_capture.getvalue(), "error": err}
    finally:
        sys.stdout, sys.stderr = old_stdout, old_stderr

@tool(name_or_callable="python_code_executor", parse_docstring=True)
def python_code_executor(
    code: str,
    description: str,
    state: Annotated[dict, InjectedState],
    tool_call_id: Annotated[str, InjectedToolCallId],
) -> str:
    """
    Executes the given Python code and returns the output.
    
    Args:
        code (str): The Python code to execute.
        description (str): A short description of the code being executed.
    
    Returns:
        str: The output of the executed code.
    """
    print("Executing code in python_code_executor: ", description, "\n")
    result = _run_python_safely(code)

    existing_reports = state.get("report", [])
    

    if 'error' in result:
        # print("Result from python_code_executor: ", result['error'])
        current_report = {
            "task": description,
            "code": code,
            "result": result.get("error", ""),
        }
        existing_reports.append(current_report)
        return Command(
            update={
                "scratchpad": [
                    ToolMessage(
                        content=f"Error executing code: {result['error']}",
                        tool_call_id=tool_call_id,
                        name="python_code_executor"
                    )
                ],
                "report": existing_reports,
            }
        )
    else:
        print("Result from python_code_executor: ", result['stdout'])
        current_report = {
            "task": description,
            "code": code,
            "result": result.get("stdout", ""),
        }
        existing_reports.append(current_report)
        return Command(
            update={
                "scratchpad": [
                    ToolMessage(
                        content=result['stdout'],
                        tool_call_id=tool_call_id,
                        name="python_code_executor"
                    )
                ],
                "report": existing_reports
            }
        )

TOOLS = [python_code_executor]

llm_med_with_code_exec_tool = llm_med.bind_tools(TOOLS, allowed_function_names=["python_code_executor"])
llm_high_with_code_exec_tool = llm_high.bind_tools(TOOLS, allowed_function_names=["python_code_executor"])

# %%
class ReportModel(BaseModel):
    task: str = Field(description="The task to be performed by the data-analysis agent.")
    code: str = Field(description="The code to be executed by the data-analysis agent that performs the requested task.")
    result: str = Field(description="The result of code execution.")

class State(TypedDict):
    """State for the analyst agent."""
    scratchpad: Annotated[list[BaseMessage], add_messages] = Field(default=[], description="The scratchpad for the agent.")
    table_id: str = Field(description="The ID of the table being queried.")
    question: str = Field(description="The question asked by the user.")
    analysis_plan: str = Field(description="The rough analysis plan for the agent to follow.")
    context: str = Field(default=None, description="The context for the agent to use.")
    iters: int = Field(default=0, description="The number of iterations the agent has gone through.")
    report: List[ReportModel] = Field(default=[], description="The report generated by the agent.")

# %%
cso_archive_reader = JSONStatArchiveDB(compression_level=12)

# %%
SYSTEM_PROMPT_ANALYST = dedent(
    f"""\
        # ROLE: I am a Data Analyst Agent that has access to Python-shell tool/function - `python_code_executor(code: str, description: str)`.

        # INSTRUCTIONS:
            - I call the `python_code_executor` tool to analyse the data.
            - Once I feel I know enough, I give a crisp and concise answer to the user's question.

        # NOTE:
            - The python-script should import necessary libraries (pandas, numpy, os, pathlib, etc) to read the CSV file and perform data manipulation 
            - The python-script use `print` statements for printing any statistics that you need to fetch.
            - In a single tool-call to `python_code_executor`, I ask for a single statistic to be fetched.
            - I keep the commentary limited in this step.
            - Once I have enough statistics to answer the user's question, I give a crisp and concise answer to user's question, with proper data backing it up.
        
        # WARNINGS:
            - For tool-calls to `python_code_executor` tool, only send the python code as `code` parameter
            - Do not include any visualizations or plots in the code.
            - In case I get reported back with any errors in executing the python code, I should make necessary corrections and call the python_code_executor tool to re-run the code.
            - The "Analysis-Plan" provided to me is a rough plan, I should adapt it as per the data available in the table.
        
        # TIPS:
            - For high cardinality columns, consider using simple keyword based filtering (like `str.contains('abc|xyz')`). Also consider items / categories related to said keywords.
    """
)

def analyst_agent(state: State) -> str:
    """
    The analyst agent has access to the Python-Shell tool and uses it answer the user query by analysing the data available in context.

    Args:
        state (State): The state containing the messages and other data.
    
    Returns:
        str: The response from the analyst agent.
    """
    table_id = state["table_id"]
    question = state["question"]
    analysis_plan = state["analysis_plan"]
    context = state["context"]
    old_messages = state["scratchpad"]
    report = state.get("report", [])

    system_prompt = SYSTEM_PROMPT_ANALYST
    iters = state.get("iters", 0)
    iters += 1

    context = f"CONTEXT:\n{context}\n\nANALYSIS PLAN:\n{analysis_plan}"
    msgs = [
        SystemMessage(content=system_prompt, name="analyst_agent"),
        SystemMessage(content=context, name="analyst_agent"),
        HumanMessage(content=question, name="analyst_agent"),
    ] + old_messages
    
    if iters <= 10:
        print("Running data-analyst agent...")
        res = llm_med_with_code_exec_tool.invoke(msgs)
    else:
        print("Stopping tool-calls as max-iterations reached. Generating final response...")
        res = llm_med.invoke(msgs)
        return {"scratchpad": [res], "iters": iters, "context": context, "report": report}

    # if isinstance(res, AIMessage):
    return {"scratchpad": [res], "iters": iters, "context": context, "report": report}
    # else:
    #     res = AIMessage("Error generating code.")
    #     return {"scratchpad": [res], "iters": iters, "context": context, "report": report}

# %%
def has_tool_calls(msg: AIMessage) -> bool:
    """
    Check if the AIMessage has tool calls.
    
    Args:
        msg (AIMessage): The AI message to check.
    
    Returns:
        bool: True if the message has tool calls, False otherwise.
    """
    return getattr(msg, "tool_calls", []) != [] or \
           bool(getattr(msg, "additional_kwargs", {}).get("function_call") or \
                getattr(msg, "additional_kwargs", {}).get("tool_calls"))


def custom_tools_condition(state: State) -> bool:
    """
    Route the LLM based on tool calls in the last message.
    
    Args:
        state (State): The current state of the graph.
    
    Returns:
        str: "tools" if the last message has tool calls, "end" otherwise.
    """
    messages_key = "scratchpad"
    if isinstance(state, list):
        ai_message = state[-1]
    elif isinstance(state, dict) and (messages := state.get(messages_key, [])):
        ai_message = messages[-1]
    elif messages := getattr(state, messages_key, []):
        ai_message = messages[-1]
    else:
        raise ValueError(f"No messages found in input state to tool_edge: {state}")
    if hasattr(ai_message, "tool_calls") and len(ai_message.tool_calls) > 0:
        return "tools"
    return "__end__"

# %%
tool_node = ToolNode(TOOLS, messages_key="scratchpad")

analyst_graph_builder = StateGraph(State)

analyst_graph_builder.add_node("analyst_agent", analyst_agent)
analyst_graph_builder.add_node("tools", tool_node)

analyst_graph_builder.add_edge(START, "analyst_agent")
analyst_graph_builder.add_conditional_edges("analyst_agent", custom_tools_condition, {"__end__": END, "tools": "tools"})
analyst_graph_builder.add_edge("tools", "analyst_agent")

analyst_graph = analyst_graph_builder.compile()
analyst_graph

# %% [markdown]
# ## Fixing context-isolation problem
#
# state:
#     - messages: List[str]
#     - relevant_docs: List[Dict]
#         - table_id: str
#         - context: str
#         - analysis_plan: str
#     - question: str
#     - iter: int
#
# reviewer-agent
# - has access to data-cso hybrid-retrieval tool - given a user prompt, it may choose to call this hybrid-retrieval tool. This tool updates the `relevant_docs` in state, and also returns a ToolMessage containing all context for all tables it retrieved [CHANGE: I've integrated the planner part in this tool itself, so no 2 separate tools now...]
# - [OBSELETE; ignore] it also has access to the planner tool, which is basically an agent. it takes in the `messages`, creates a low-level plan for each data-source analysis and updates the `relevant_docs` with the plan. Also it returns a ToolMessage containing the plan for all tables
# - finally, it has access to the data-analyst subgraph as a tool. It can make multiple tool-calls to this tool. The tool node containing this subgraph will call the subgraph with the `table_id`, `question`, `analysis_plan`, and the `context`.
#
# Giving this level of autonomy may have the following effect:
# - Pros: context-isolation problem may be fixed
# - Cons: redundant recursive loops, uncertainty in making tool-calls / malformed tool-calls, hallucinations, or even premature answering

# %%
# LLM Structured Output Models
class AnalysisPlanSubModel(BaseModel):
    table_id: str = Field(description="The ID of the relevant table.")
    analysis_plan: List[str] = Field(description="The low-level analysis plan for the table. Contains a list of steps.")

class AnalysisPlanModel(BaseModel):
    plans: List[AnalysisPlanSubModel] = Field(description="List of analysis plans for relevant tables.")


# Graph State Models
class RelevantTablesModel(BaseModel):
    table_id: str = Field(description="The ID of the relevant table.")
    context: str = Field(description="The statistical data profile of the table.")
    analysis_plan: List[str] = Field(description="The low-level analysis plan for the table. Contains a list of steps.")


class ParentState(TypedDict):
    """State for the parent graph."""
    messages: Annotated[list[BaseMessage], add_messages] = Field(default=[], description="The messages for the parent graph.")
    question: str = Field(default=None, description="The question asked by the user.")
    iter: int = Field(default=0, description="The iteration count for the current state.")
    relevant_tables_ids: List[RelevantTablesModel] = Field(default=[], description="List of relevant table IDs, their contexts, and analysis plans.")
    reports: Dict[str, List[ReportModel]] = Field(default={}, description="Dictionary mapping table IDs to their analysis reports.")

# %%
from src.helpers.hybrid_retrieval import HybridRetrieval


retriever = HybridRetrieval(top_k_stage_1=200, top_k_stage_2=20)


def _create_table_analysis(df: pd.DataFrame, table_id: str) -> dict:
    """
    Analyzes the table and returns a dictionary with the analysis results.

    Args:
        df (pd.DataFrame): The DataFrame containing the CSO data.

    Returns:
        dict: A dictionary containing the analysis results.
    """
    csv_fp = f"cache/{table_id}.csv"
    try:
        table_shape = df.shape
        table_sample = pd.concat([df.head(5), df.tail(5)]) if len(df) > 10 else df
        
        table_info_df = pd.DataFrame({
            "columns": df.columns,
            "dtypes": [str(df[col].dtype) for col in df.columns],
            "nunique": [df[col].nunique() if df[col].nunique() <= 50 else '>50' for col in df.columns],
            "nulls": [df[col].isnull().sum() for col in df.columns]
        })

        context_list = [
            f"**Table ID:** {table_id}",
            f"- **CSV File Path**: {csv_fp}",
            f"- **Table Shape**: {table_shape}",
            "- **Table Info**:",
            table_info_df.to_string(index=False),
            "- **Table Sample (first and last 5 rows)**:",
            table_sample.to_string(index=False),
        ]

    except Exception as e:
        context_list = None

    return context_list


@tool("hybrid_retrieval_tool", parse_docstring=True)
def hybrid_retrieval_tool(
    user_prompt: str,
    tool_call_id: Annotated[str, InjectedToolCallId],
) -> Command:
    """
    Tool to invoke the hybrid retrieval and return relevant table IDs.
    
    Args:
        user_prompt (str): The user's question or prompt.

    Returns:
        Command: The command to update the chat with the relevant table IDs.
    """
    print("HYBRID_RETRIEVAL_TOOL: Invoking hybrid retrieval tool...")
    relevant_tables_ids = retriever.search(query=user_prompt)
    print(f"HYBRID_RETRIEVAL_TOOL: LLM selected {len(relevant_tables_ids)} relevant tables.")

    if not relevant_tables_ids:
        print("HYBRID_RETRIEVAL_TOOL: No relevant tables found.")
        return Command(
            update={
                "messages": [
                    AIMessage(content="No relevant tables found.")
                ]
            }
        )
    else:
        print(f"HYBRID_RETRIEVAL_TOOL: Found {len(relevant_tables_ids)} relevant tables.")

        csv_save_dir = "cache/"
        relevant_tables_metadata = []
        table_contexts_list = []
        contexts_dict = {}

        for table_id in relevant_tables_ids:
            csv_fp = csv_save_dir + f"{table_id}.csv"

            # check if "<table_id>.csv" exists. If not, read the pyjstat-file from artifacts and save the DataFrame as "<table_id>.csv"
            if not os.path.exists(csv_fp):
                for _, ds, _ in cso_archive_reader.read("artifacts/cso_bkp/cso_archive/jsonstat_archive.sqlite", table_id=table_id, with_labels=True):
                    df: pd.DataFrame = pyjstat.from_json_stat(ds)[0]
                df.to_csv(csv_fp, index=False)
            else:
                df = pd.read_csv(csv_fp)
            
            context_list = _create_table_analysis(df, table_id)
            context = "\n".join(context_list) if context_list else "No context available."
            table_contexts_list.append(context)
            contexts_dict[table_id] = context
            
        table_contexts = "\n\n".join(table_contexts_list)
        system_message_list = [
            "# GOAL: I am a Planner agent. Given a user-query and the relevant tables in context, I need to create a low-level plan for the data-analyst agent to carry out its analysis step-by-step to achieve the desired outcome.",
            "",
            "# CONTEXT:",
            table_contexts,
            "",
            "# RETURN FORMAT:",
            "[",
            "    {",
            "        \"table_id\": <table_id>,",
            "        \"analysis_plan\": <analysis_plan>",
            "    }",
            "]"
        ]
        system_message = "\n".join(system_message_list)

        res = llm_med.with_structured_output(AnalysisPlanModel).invoke(
            [
                SystemMessage(content=system_message, name="planner_agent"),
                HumanMessage(content=user_prompt, name="user")
            ]
        )
        res_dict = res.model_dump()
        plans_list = res_dict["plans"]
        for table_plan in plans_list:
            table_id = table_plan["table_id"]
            analysis_plan = table_plan["analysis_plan"]

            relevant_tables_metadata.append(
                {
                    "table_id": table_id,
                    "context": contexts_dict.get(table_id, ""),
                    "analysis_plan": analysis_plan
                }
            )

        tool_message_list = []
        for relevant_table_metadata in relevant_tables_metadata:
            tool_message_list.append(f"Table ID: {relevant_table_metadata['table_id']}")
            tool_message_list.append(f"Context: {relevant_table_metadata['context']}")
            tool_message_list.append(f"Analysis Plan: {relevant_table_metadata['analysis_plan']}")
            tool_message_list.append("")

        tool_message = "\n".join(tool_message_list)

        return Command(
            update={
                "relevant_tables_ids": relevant_tables_metadata,
                "messages": [
                    ToolMessage(
                        content=tool_message,
                        tool_call_id=tool_call_id,
                        name="relevant_tables_metadata"
                    )
                ]
            }
        )

@tool("data_analyst_tool", parse_docstring=True)
def data_analyst_tool(
    table_id: str,
    # question: str,
    state: Annotated[dict, InjectedState],
    tool_call_id: Annotated[str, InjectedToolCallId],
):
    """
    Tool to invoke the data analyst agent and return the final analysis.
    
    Args:
        table_id (str): The ID of the table to analyze.
        state (dict): The current state of the conversation.
        tool_call_id (str): The ID of the tool call.

    Returns:
        Command: The command to update the chat with the data analyst's response.
    """
    question = state["question"]
    relevant_tables_metadata = state["relevant_tables_ids"]
    reports_dict = state.get("reports", {})

    for relevant_table_metadata in relevant_tables_metadata:
        if relevant_table_metadata["table_id"] == table_id:
            analysis_plan = "\n".join(relevant_table_metadata["analysis_plan"])
            context = relevant_table_metadata["context"]
            break


    print("DATA_ANALYST_TOOL: Invoking data analyst tool...")
    res = analyst_graph.invoke({"table_id": table_id, "question": question, "context": context, "analysis_plan": analysis_plan})
    last_message = res["scratchpad"][-1]
    last_report = res["report"]
    reports_dict[table_id] = reports_dict.get(table_id, []) + last_report
    print("DATA_ANALYST_TOOL: Run Successfully", last_message.content)
    return Command(
        update={
            "messages": [
                ToolMessage(
                    content=last_message.content,
                    tool_call_id=tool_call_id,
                    name="data_analyst_tool",
                )
            ],
            "reports": reports_dict
        }
    )

@tool("provenance_tool", parse_docstring=True)
def provenance_tool(
    table_id: str,
    state: Annotated[dict, InjectedState],
    tool_call_id: Annotated[str, InjectedToolCallId],
):
    """
    Tool to retrieve the provenance information (analysis report containing low-level code used for generating analysis) for a specific table.

    Args:
        table_id (str): The ID of the table to retrieve provenance information for.
        state (dict): The current state of the conversation.
        tool_call_id (str): The ID of the tool call.

    Returns:
        Command: The command to update the chat with the provenance information.
    """
    report_text_list = []
    reports_dict = state.get("reports", {})
    report = reports_dict.get(table_id, [])

    for i, entry in enumerate(report):
        report_text_list.append(f"### Task {i+1}: {entry['task']}\n")
        report_text_list.append(f"**Code:**\n```python\n{entry['code']}\n```")
        report_text_list.append(f"**Output:**\n```python\n{entry['result']}\n```")
        report_text_list.append("")

    report_text = "\n".join(report_text_list)

    return Command(
        update={
            "messages": [
                ToolMessage(
                    content=report_text,
                    tool_call_id=tool_call_id,
                    name="provenance_tool",
                )
            ]
        }
    )

NEW_TOOLS = [hybrid_retrieval_tool, data_analyst_tool, provenance_tool]
llm_med_with_tools_poc = llm_med.bind_tools(NEW_TOOLS)

# %%
def _to_text(content) -> str:
    # Handles str, list[str], list[dict-like parts], or anything else.
    if isinstance(content, str):
        return content
    if isinstance(content, list):
        pieces = []
        for part in content:
            if isinstance(part, str):
                pieces.append(part)
            elif isinstance(part, dict):
                # Gemini often uses {"type":"text","text": "..."} parts
                pieces.append(part.get("text", ""))
            else:
                # Some wrappers expose objects with a .text attr
                pieces.append(getattr(part, "text", str(part)))
        return "\n".join(pieces)
    return str(content)

def _coerce_ai_to_text(ai: AIMessage) -> AIMessage:
    print(ai)
    text = _to_text(ai.content)
    print(text)
    # Rewrap as a new AIMessage keeping useful metadata
    return AIMessage(
        content=text,
        additional_kwargs=ai.additional_kwargs,
        response_metadata=getattr(ai, "response_metadata", None)
    )


reviewer_system_prompt = dedent(
    """\
        # GOAL: I'm a helpful assistant. My job is to answer the user-question using all the facts available.

        # INSTRUCTIONS:
        - I have the following tools available for my tasks:
            1. hybrid_retrieval_tool: To retrieve relevant table IDs from CSO-DATA based on user queries.
            2. data_analyst_tool: To run the analysis on the retrieved tables.
            3. provenance_tool: To fetch the provenance information (analysis report containing low-level code used for generating analysis) for a specific table.
        - Once I have the relevant data from tables, I will use the `data_analyst_tool` to perform the analysis by invoking it with each retrieved `table_id`
        - Once I have the results from the analysis, I will answer the user's question in detail, using only the insights gained from the analysis.
        - I will cite the sources of my information (table-IDs) against each fact.
        - If the user explicitly asks a follow-up question for the code / filters / methodology used in generating the insights, I will retrieve the provenance information by calling the `provenance_tool`, and only then answer the user follow-up question

        # RETURN FORMAT:
        - The final answer containing text / tables should be in Markdown format
    """
)

def reviewer_agent(state: ParentState):
    response = {}
    iter = state.get("iter", 0) + 1
    messages = state["messages"]

    if isinstance(messages[-1], HumanMessage):
        if state.get("question", None) is not None and messages[-1].content != state["question"]:
            iter = 0 # reset iteration for new questions

        response["question"] = messages[-1].content
    
    res = llm_med_with_tools_poc.invoke(
        [SystemMessage(content=reviewer_system_prompt, name="reviewer_agent")] + messages,
        config={"response_mime_type": "text/plain"},

    )

    if iter > 12:
        response["messages"] = [AIMessage("Max iterations reached, ending...")]
    else:
        print(isinstance(res, AIMessage))
        print(has_tool_calls(res))
        res = _coerce_ai_to_text(res) if isinstance(res, AIMessage) and not has_tool_calls(res) else res
        response["messages"] = [res]
    
    response["iter"] = iter

    return response

# %%
new_tool_node = ToolNode(NEW_TOOLS)

new_graph_builder = StateGraph(ParentState)

new_graph_builder.add_node("reviewer_agent", reviewer_agent)
new_graph_builder.add_node("tools", new_tool_node)

new_graph_builder.add_edge(START, "reviewer_agent")
new_graph_builder.add_conditional_edges("reviewer_agent", tools_condition)
new_graph_builder.add_edge("tools", "reviewer_agent")

app = new_graph_builder.compile()
app

# %%
question = "QUESTION: Give me the breakdown of renewable energy resources as a percentage share and absolute numbers in 2022 in ireland."
question = "QUESTION: How's the energy production in ireland over the years? Do a detailed comparison of renewable vs non-renewable share of energy"
# question = "QUESTION: How's the wind energy production over the years?"
question = "QUESTION: Did the Ukraine war have any impact on the energy production in ireland??"
# question = "QUESTION: How has nuclear energy done over the years in ireland?"
# question = "QUESTION: What's the impact of climate change on energy production in ireland?"
# question = "QUESTION: How's the energy production in ireland over 2021-2025? Do a detailed comparison of renewable vs non-renewable share of energy"
# question = "QUESTION: What's the total agricultural area in Ireland? Answer in detail."
# question = "detailed statistics on cosmetics, toileteries and related items production in prodcom data for ireland"
# question = "detailed statistics on lignin based products and related items production in prodcom data for ireland"
question = "Population growth in ireland over the last 2 decades?"
# question = "What are the production volume and value for agriculture sector. Within the agriculture sector, what is the share of different sector w.r.t volume and value."

res = app.invoke({"messages": [HumanMessage(content=question, name="user")]})
# Out:
# True
# True
# HYBRID_RETRIEVAL_TOOL: Invoking hybrid retrieval tool...
# HYBRID_RETRIEVAL_TOOL: LLM selected 3 relevant tables.
# HYBRID_RETRIEVAL_TOOL: Found 3 relevant tables.
# True
# True
# DATA_ANALYST_TOOL: Invoking data analyst tool...
# Running data-analyst agent...
# Executing code in python_code_executor:  Extracting population for 2011
#
# Result from python_code_executor:  Population in 2011: 4588252.0
#
# Running data-analyst agent...
# Executing code in python_code_executor:  Extracting population for 2016
#
# Result from python_code_executor:  Population in 2016: 4761865.0
#
# Running data-analyst agent...
# DATA_ANALYST_TOOL: Run Successfully The population of Ireland increased from 4,588,252 in 2011 to 4,761,865 in 2016, representing a growth of 173,613 people or approximately 3.78% over this 5-year period. Please note that the provided data only covers the period between 2011 and 2016, not the full last two decades.
# True
# True
# DATA_ANALYST_TOOL: Invoking data analyst tool...
# Running data-analyst agent...
# Executing code in python_code_executor:  Calculating the total population of Ireland in 2002.
#
# Result from python_code_executor:  The total population of Ireland in 2002 was: 3,917,203
#
# Running data-analyst agent...
# DATA_ANALYST_TOOL: Run Successfully I apologize, but I only have population data for the year 2002. I cannot provide information on population growth over the last two decades with the available data. In 2002, the total population of Ireland was 3,917,203.
# True
# True
# DATA_ANALYST_TOOL: Invoking data analyst tool...
# Running data-analyst agent...
# DATA_ANALYST_TOOL: Run Successfully
# True
# False
# content='The population of Ireland has experienced significant growth over the last two decades.\n\n*   In 2002, the total population was **3,917,203** (Source: B0205).\n*   By 2011, the population increased to **4,588,252** (Source: E3002).\n*   In 2016, the population further grew to **4,761,865** (Source: E3002).\n\nOverall, from 2002 to 2016, the population of Ireland grew by **844,662** people.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--e4dc4539-1778-4681-a517-ac7024032fd4-0' usage_metadata={'input_tokens': 2251, 'output_tokens': 307, 'total_tokens': 2558, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 157}}
# The population of Ireland has experienced significant growth over the last two decades.
#
# *   In 2002, the total population was **3,917,203** (Source: B0205).
# *   By 2011, the population increased to **4,588,252** (Source: E3002).
# *   In 2016, the population further grew to **4,761,865** (Source: E3002).
#
# Overall, from 2002 to 2016, the population of Ireland grew by **844,662** people.

# %%
res
# Out:
# {'messages': [HumanMessage(content='Population growth in ireland over the last 2 decades?', additional_kwargs={}, response_metadata={}, name='user', id='a694281b-a70e-4b1e-b310-acda22ec721a'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'hybrid_retrieval_tool', 'arguments': '{"user_prompt": "Population growth in ireland over the last 2 decades?"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--e0b08215-5fd4-4e8f-8b6b-426105d16272-0', tool_calls=[{'name': 'hybrid_retrieval_tool', 'args': {'user_prompt': 'Population growth in ireland over the last 2 decades?'}, 'id': 'd635aca8-2a59-4751-9762-1e09c388a45c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 478, 'output_tokens': 97, 'total_tokens': 575, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 66}}),
#   ToolMessage(content='Table ID: E3002\nContext: **Table ID:** E3002\n- **CSV File Path**: cache/E3002.csv\n- **Table Shape**: (5508, 7)\n- **Table Info**:\n                     columns  dtypes nunique  nulls\n                   Statistic  object       1      0\n                         Sex  object       3      0\n           Age Last Birthday  object     >50      0\n                  CensusYear   int64       2      0\nAggregate Town or Rural Area  object       3      0\n         At Each Year of Age  object       3      0\n                       value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n              Statistic        Sex  Age Last Birthday  CensusYear Aggregate Town or Rural Area             At Each Year of Age     value\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State                      Population 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State Population at or under this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State  Population at or over this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area                      Population 2846882.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area Population at or under this age 2846882.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area Population at or under this age 1527054.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area  Population at or over this age     225.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area                      Population     147.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area Population at or under this age  880383.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area  Population at or over this age     147.0\nAnalysis Plan: ["Filter the data to include rows where \'Statistic\' is \'Population 2011 to 2016\', \'Aggregate Town or Rural Area\' is \'State\', \'Age Last Birthday\' is \'All ages\', and \'At Each Year of Age\' is \'Population\'.", "Select \'CensusYear\' and \'value\' columns to get the total population for the years 2011 and 2016."]\n\nTable ID: B0205\nContext: **Table ID:** B0205\n- **CSV File Path**: cache/B0205.csv\n- **Table Shape**: (612, 6)\n- **Table Info**:\n            columns  dtypes nunique  nulls\n          Statistic  object       1      0\n                Sex  object       3      0\n  Age Last Birthday  object     >50      0\nAt Each Year of Age  object       2      0\n         CensusYear   int64       1      0\n              value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n       Statistic        Sex  Age Last Birthday             At Each Year of Age  CensusYear     value\n2002  Population Both sexes           All ages                      Population        2002 3917203.0\n2002  Population Both sexes           All ages Population at or under this age        2002 3917203.0\n2002  Population Both sexes       Under 1 year                      Population        2002   54499.0\n2002  Population Both sexes       Under 1 year Population at or under this age        2002   54499.0\n2002  Population Both sexes             1 year                      Population        2002   55362.0\n2002  Population     Female           98 years Population at or under this age        2002 1970691.0\n2002  Population     Female           99 years                      Population        2002     140.0\n2002  Population     Female           99 years Population at or under this age        2002 1970831.0\n2002  Population     Female 100 years and over                      Population        2002     208.0\n2002  P ...
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'data_analyst_tool', 'arguments': '{"table_id": "E3002"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--34d4e673-2019-455a-bb69-547eb0ef4f1c-0', tool_calls=[{'name': 'data_analyst_tool', 'args': {'table_id': 'E3002'}, 'id': 'abb1dad0-93a0-49c4-90b2-f24c2af23148', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1972, 'output_tokens': 214, 'total_tokens': 2186, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 190}}),
#   ToolMessage(content='The population of Ireland increased from 4,588,252 in 2011 to 4,761,865 in 2016, representing a growth of 173,613 people or approximately 3.78% over this 5-year period. Please note that the provided data only covers the period between 2011 and 2016, not the full last two decades.', name='data_analyst_tool', id='374be5d6-3f1f-4ae3-9576-4e161de8d128', tool_call_id='abb1dad0-93a0-49c4-90b2-f24c2af23148'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'data_analyst_tool', 'arguments': '{"table_id": "B0205"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--3b2d950c-7531-4717-9dc9-a54000206ed5-0', tool_calls=[{'name': 'data_analyst_tool', 'args': {'table_id': 'B0205'}, 'id': 'f7dc82a7-924a-49ab-824e-4486b1867199', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2112, 'output_tokens': 212, 'total_tokens': 2324, 'input_token_details': {'cache_read': 1694}, 'output_token_details': {'reasoning': 188}}),
#   ToolMessage(content='I apologize, but I only have population data for the year 2002. I cannot provide information on population growth over the last two decades with the available data. In 2002, the total population of Ireland was 3,917,203.', name='data_analyst_tool', id='0148c4bb-ec99-4e4b-ae29-eff861d07403', tool_call_id='f7dc82a7-924a-49ab-824e-4486b1867199'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'data_analyst_tool', 'arguments': '{"table_id": "overall_analysis"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--3129760c-bb07-4b4e-bc87-d2cfeecde677-0', tool_calls=[{'name': 'data_analyst_tool', 'args': {'table_id': 'overall_analysis'}, 'id': 'fa7cb090-607d-4048-9f2b-204aa909b1cd', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2212, 'output_tokens': 227, 'total_tokens': 2439, 'input_token_details': {'cache_read': 1700}, 'output_token_details': {'reasoning': 205}}),
#   ToolMessage(content='', name='data_analyst_tool', id='206a7863-e00c-4f72-8253-c1d0977a96a8', tool_call_id='fa7cb090-607d-4048-9f2b-204aa909b1cd'),
#   AIMessage(content='The population of Ireland has experienced significant growth over the last two decades.\n\n*   In 2002, the total population was **3,917,203** (Source: B0205).\n*   By 2011, the population increased to **4,588,252** (Source: E3002).\n*   In 2016, the population further grew to **4,761,865** (Source: E3002).\n\nOverall, from 2002 to 2016, the population of Ireland grew by **844,662** people.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='70792ead-8e32-4d2b-a9ae-a752d07dcfb0')],
#  'question': 'Population growth in ireland over the last 2 decades?',
#  'iter': 5,
#  'relevant_tables_ids': [{'table_id': 'E3002',
#    'context': '**Table ID:** E3002\n- **CSV File Path**: cache/E3002.csv\n- **Table Shape**: (5508, 7)\n- **Table Info**:\n                     columns  dtypes nunique  nulls\n                   Statistic  object       1      0\n                         Sex  object       3      0\n           Age Last Birthday  object     >50      0\n                  CensusYear   int64       2      0\nAggregate Town or Rural Area  object       3      0\n         At Each Year of Age  object       3      0\n                       value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n              Statistic        Sex  Age Last Birthday  CensusYear Aggregate Town or Rural Area             At Each Year of Age     value\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State                      Population 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State Population at or under this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State  Population at or over this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area                      Population 2846882.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area Population at or under this age 2846882.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area Population at or under this age 1527054.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area  Population at or over this age     225.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area                      Population     147.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area Population at or under this age  880383.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area  Population at or over this age     147.0',
#    'analysis_plan': ["Filter the data to include rows where 'Statistic' is 'Population 2011 to 2016', 'Aggregate Town or Rural Area' is 'State', 'Age Last Birthday' is 'All ages', and 'At Each Year of Age' is 'Population'.",
#     "Select 'CensusYear' and 'value' columns to get the total population for the years 2011 and 2016."]},
#   {'table_id': 'B0205',
#    'context': '**Table ID:** B0205\n- **CSV File Path**: cache/B0205.csv\n- **Table Shape**: (612, 6)\n- **Table Info**:\n            columns  dtypes nunique  nulls\n          Statistic  object       1      0\n                Sex  object       3      0\n  Age Last Birthday  object     >50      0\nAt Each Year of Age  object       2      0\n         CensusYear   int64       1      0\n              value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n       Statistic        Sex  Age Last Birthday             At Each Year of Age  CensusYear     value\n2002  Population Both sexes           All ages                      Population        2002 3917203.0\n2002  Population Both sexes           All ages Population at or under this age        2002 3917203.0\n2002  Population Both sexes       Under 1 year                      Population        2002   54499.0\n2002  Population Both sexes       Under 1 year Population at or under this age        2002   54499.0\n2002  Population Both sexes             1 year                      Population        2002   55362.0\n2002  Population     Female           98 years Population at or under this age        2002 1970691.0\n2002  Population     Female           99 years                      Population        2002     140.0\n2002  Population     Female           99 years Population at or under this age        2002 1970831.0\n2002  Population     Female 100 years and over                      Population        2002     208.0\n2002  Population     Female 100 years and over Population at or under this age        2002 1971039.0',
#    'analysis_plan': ["Filter the data to include rows where 'Statistic' is '2002 Population', 'Age Last Birthday' is 'All ages', and 'At Each Year of Age' is 'Population'.",
#     "Select 'CensusYear' and 'value' columns to get the total population for the year 2002."]},
#   {'table_id': 'overall_analysis',
#    'context': '',
#    'analysis_plan': ['Combine the filtered data from E3002 and B0205.',
#     "Sort the combined data by 'CensusYear' in ascending order.",
#     'Calculate the population growth by finding the difference in population values between the earliest year (2002) and the latest year (2016) to show the overall growth over the last two decades.',
#     'Present the population figures for 2002, 2011, and 2016, and the calculated total population growth.']}],
#  'reports': {'E3002': [{'task': 'Extracting population for 2011',
#     'code': '\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2011 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2011)]["value"].iloc[0]\n\nprint(f"Population in 2011: {population_2011}")\n',
#     'result': 'Population in 2011: 4588252.0\n'},
#    {'task': 'Extracting population for 2016',
#     'code': '\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2016 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2016)]["value"].iloc[0]\n\nprint(f"Population in 2016: {population_2016}")\n',
#     'result': 'Population in 2016: 4761865.0\n'}],
#   'B0205': [{'task': 'Calculating the total population of Ireland in 2002.',
#     'code': '\nimport pandas as pd\n\ndf = pd.read_csv("cache/B0205.csv")\n\n# Filter for total population in 2002\ntotal_population_2002 = df[(df["Age Last Birthday"] == "All ages") & \n                           (df["At Each Year of Age"] == "Population")]\n\n# Get the value for total population\npopulation_value = total_population_2002["value"].iloc[0]\n\nprint(f"The total population of Ireland in 2002 was: {population_value:,.0f}")\n',
#     'result': 'The total population of Ireland in 2002 was: 3,917,203\n'}],
#   'overall_analysis': []}}

# %%
print(res["messages"][-1].content)
# Out:
# The population of Ireland has experienced significant growth over the last two decades.
#
# *   In 2002, the total population was **3,917,203** (Source: B0205).
# *   By 2011, the population increased to **4,588,252** (Source: E3002).
# *   In 2016, the population further grew to **4,761,865** (Source: E3002).
#
# Overall, from 2002 to 2016, the population of Ireland grew by **844,662** people.

# %%
question_follow_up = "please show me the code you used for your analysis?"

res_follow_up = app.invoke({
    "messages": res["messages"] + [HumanMessage(content=question_follow_up)],
    "relevant_tables_ids": res["relevant_tables_ids"],
    "reports": res["reports"]
})
# Out:
# True
# True
# True
# True
# True
# True
# True
# False
# content=['The code used for the analysis of population growth in Ireland is as follows:\n\n### For Table E3002 (Population 2011 to 2016)\n\n**Task 1: Extracting population for 2011**', '```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2011 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2011)]["value"].iloc[0]\n\nprint(f"Population in 2011: {population_2011}")\n\n```', '\n\n**Task 2: Extracting population for 2016**', '```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2016 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2016)]["value"].iloc[0]\n\nprint(f"Population in 2016: {population_2016}")\n\n```', '\n\n### For Table B0205 (Population 2002)\n\n**Task 1: Calculating the total population of Ireland in 2002.**', '```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/B0205.csv")\n\n# Filter for total population in 2002\ntotal_population_2002 = df[(df["Age Last Birthday"] == "All ages") & \n                           (df["At Each Year of Age"] == "Population")]\n\n# Get the value for total population\npopulation_value = total_population_2002["value"].iloc[0]\n\nprint(f"The total population of Ireland in 2002 was: {population_value:,.0f}")\n\n```'] additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []} id='run--fbe5d093-c8ea-4ea2-a70d-cb6ae8fe6fc3-0' usage_metadata={'input_tokens': 3218, 'output_tokens': 664, 'total_tokens': 3882, 'input_token_details': {'cache_read': 2653}, 'output_token_details': {'reasoning': 114}}
# The code used for the analysis of population growth in Ireland is as follows:
#
# ### For Table E3002 (Population 2011 to 2016)
#
# **Task 1: Extracting population for 2011**```python
#
# import pandas as pd
#
# df = pd.read_csv("cache/E3002.csv")
#
# population_2011 = df[(df["Statistic"] == "Population 2011 to 2016") &
#                      (df["Aggregate Town or Rural Area"] == "State") &
#                      (df["Age Last Birthday"] == "All ages") &
#                      (df["At Each Year of Age"] == "Population") &
#                      (df["CensusYear"] == 2011)]["value"].iloc[0]
#
# print(f"Population in 2011: {population_2011}")
#
# ```
#
# **Task 2: Extracting population for 2016**```python
#
# import pandas as pd
#
# df = pd.read_csv("cache/E3002.csv")
#
# population_2016 = df[(df["Statistic"] == "Population 2011 to 2016") &
#                      (df["Aggregate Town or Rural Area"] == "State") &
#                      (df["Age Last Birthday"] == "All ages") &
#                      (df["At Each Year of Age"] == "Population") &
#                      (df["CensusYear"] == 2016)]["value"].iloc[0]
#
# print(f"Population in 2016: {population_2016}")
#
# ```
#
# ### For Table B0205 (Population 2002)
#
# **Task 1: Calculating the total population of Ireland in 2002.**```python
#
# import pandas as pd
#
# df = pd.read_csv("cache/B0205.csv")
#
# # Filter for total population in 2002
# total_population_2002 = df[(df["Age Last Birthday"] == "All ages") &
#                            (df["At Each Year of Age"] == "Population")]
#
# # Get the value for total population
# population_value = total_population_2002["value"].iloc[0]
#
# print(f"The total population of Ireland in 2002 was: {population_value:,.0f}")
#
# ```

# %%
res_follow_up
# Out:
# {'messages': [HumanMessage(content='Population growth in ireland over the last 2 decades?', additional_kwargs={}, response_metadata={}, name='user', id='a694281b-a70e-4b1e-b310-acda22ec721a'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'hybrid_retrieval_tool', 'arguments': '{"user_prompt": "Population growth in ireland over the last 2 decades?"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--e0b08215-5fd4-4e8f-8b6b-426105d16272-0', tool_calls=[{'name': 'hybrid_retrieval_tool', 'args': {'user_prompt': 'Population growth in ireland over the last 2 decades?'}, 'id': 'd635aca8-2a59-4751-9762-1e09c388a45c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 478, 'output_tokens': 97, 'total_tokens': 575, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 66}}),
#   ToolMessage(content='Table ID: E3002\nContext: **Table ID:** E3002\n- **CSV File Path**: cache/E3002.csv\n- **Table Shape**: (5508, 7)\n- **Table Info**:\n                     columns  dtypes nunique  nulls\n                   Statistic  object       1      0\n                         Sex  object       3      0\n           Age Last Birthday  object     >50      0\n                  CensusYear   int64       2      0\nAggregate Town or Rural Area  object       3      0\n         At Each Year of Age  object       3      0\n                       value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n              Statistic        Sex  Age Last Birthday  CensusYear Aggregate Town or Rural Area             At Each Year of Age     value\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State                      Population 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State Population at or under this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State  Population at or over this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area                      Population 2846882.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area Population at or under this age 2846882.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area Population at or under this age 1527054.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area  Population at or over this age     225.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area                      Population     147.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area Population at or under this age  880383.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area  Population at or over this age     147.0\nAnalysis Plan: ["Filter the data to include rows where \'Statistic\' is \'Population 2011 to 2016\', \'Aggregate Town or Rural Area\' is \'State\', \'Age Last Birthday\' is \'All ages\', and \'At Each Year of Age\' is \'Population\'.", "Select \'CensusYear\' and \'value\' columns to get the total population for the years 2011 and 2016."]\n\nTable ID: B0205\nContext: **Table ID:** B0205\n- **CSV File Path**: cache/B0205.csv\n- **Table Shape**: (612, 6)\n- **Table Info**:\n            columns  dtypes nunique  nulls\n          Statistic  object       1      0\n                Sex  object       3      0\n  Age Last Birthday  object     >50      0\nAt Each Year of Age  object       2      0\n         CensusYear   int64       1      0\n              value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n       Statistic        Sex  Age Last Birthday             At Each Year of Age  CensusYear     value\n2002  Population Both sexes           All ages                      Population        2002 3917203.0\n2002  Population Both sexes           All ages Population at or under this age        2002 3917203.0\n2002  Population Both sexes       Under 1 year                      Population        2002   54499.0\n2002  Population Both sexes       Under 1 year Population at or under this age        2002   54499.0\n2002  Population Both sexes             1 year                      Population        2002   55362.0\n2002  Population     Female           98 years Population at or under this age        2002 1970691.0\n2002  Population     Female           99 years                      Population        2002     140.0\n2002  Population     Female           99 years Population at or under this age        2002 1970831.0\n2002  Population     Female 100 years and over                      Population        2002     208.0\n2002  P ...
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'data_analyst_tool', 'arguments': '{"table_id": "E3002"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--34d4e673-2019-455a-bb69-547eb0ef4f1c-0', tool_calls=[{'name': 'data_analyst_tool', 'args': {'table_id': 'E3002'}, 'id': 'abb1dad0-93a0-49c4-90b2-f24c2af23148', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1972, 'output_tokens': 214, 'total_tokens': 2186, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 190}}),
#   ToolMessage(content='The population of Ireland increased from 4,588,252 in 2011 to 4,761,865 in 2016, representing a growth of 173,613 people or approximately 3.78% over this 5-year period. Please note that the provided data only covers the period between 2011 and 2016, not the full last two decades.', name='data_analyst_tool', id='374be5d6-3f1f-4ae3-9576-4e161de8d128', tool_call_id='abb1dad0-93a0-49c4-90b2-f24c2af23148'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'data_analyst_tool', 'arguments': '{"table_id": "B0205"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--3b2d950c-7531-4717-9dc9-a54000206ed5-0', tool_calls=[{'name': 'data_analyst_tool', 'args': {'table_id': 'B0205'}, 'id': 'f7dc82a7-924a-49ab-824e-4486b1867199', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2112, 'output_tokens': 212, 'total_tokens': 2324, 'input_token_details': {'cache_read': 1694}, 'output_token_details': {'reasoning': 188}}),
#   ToolMessage(content='I apologize, but I only have population data for the year 2002. I cannot provide information on population growth over the last two decades with the available data. In 2002, the total population of Ireland was 3,917,203.', name='data_analyst_tool', id='0148c4bb-ec99-4e4b-ae29-eff861d07403', tool_call_id='f7dc82a7-924a-49ab-824e-4486b1867199'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'data_analyst_tool', 'arguments': '{"table_id": "overall_analysis"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--3129760c-bb07-4b4e-bc87-d2cfeecde677-0', tool_calls=[{'name': 'data_analyst_tool', 'args': {'table_id': 'overall_analysis'}, 'id': 'fa7cb090-607d-4048-9f2b-204aa909b1cd', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2212, 'output_tokens': 227, 'total_tokens': 2439, 'input_token_details': {'cache_read': 1700}, 'output_token_details': {'reasoning': 205}}),
#   ToolMessage(content='', name='data_analyst_tool', id='206a7863-e00c-4f72-8253-c1d0977a96a8', tool_call_id='fa7cb090-607d-4048-9f2b-204aa909b1cd'),
#   AIMessage(content='The population of Ireland has experienced significant growth over the last two decades.\n\n*   In 2002, the total population was **3,917,203** (Source: B0205).\n*   By 2011, the population increased to **4,588,252** (Source: E3002).\n*   In 2016, the population further grew to **4,761,865** (Source: E3002).\n\nOverall, from 2002 to 2016, the population of Ireland grew by **844,662** people.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='70792ead-8e32-4d2b-a9ae-a752d07dcfb0'),
#   HumanMessage(content='please show me the code you used for your analysis?', additional_kwargs={}, response_metadata={}, id='87005976-ba3c-4c32-a17f-9942734ad3a1'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'provenance_tool', 'arguments': '{"table_id": "E3002"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--e8e4baf3-b5bc-4ba7-8742-0219f7cb70c8-0', tool_calls=[{'name': 'provenance_tool', 'args': {'table_id': 'E3002'}, 'id': '46c69da7-8f7f-4a96-ad0e-6250006509bc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2414, 'output_tokens': 107, 'total_tokens': 2521, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 85}}),
#   ToolMessage(content='### Task 1: Extracting population for 2011\n\n**Code:**\n```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2011 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2011)]["value"].iloc[0]\n\nprint(f"Population in 2011: {population_2011}")\n\n```\n**Output:**\n```python\nPopulation in 2011: 4588252.0\n\n```\n\n### Task 2: Extracting population for 2016\n\n**Code:**\n```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2016 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2016)]["value"].iloc[0]\n\nprint(f"Population in 2016: {population_2016}")\n\n```\n**Output:**\n```python\nPopulation in 2016: 4761865.0\n\n```\n', name='provenance_tool', id='aeeb5ea2-bd0d-44c5-9fc4-6fbebb5e60b8', tool_call_id='46c69da7-8f7f-4a96-ad0e-6250006509bc'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'provenance_tool', 'arguments': '{"table_id": "B0205"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--aab892ed-4da6-4d6a-8ec6-89c10b770e15-0', tool_calls=[{'name': 'provenance_tool', 'args': {'table_id': 'B0205'}, 'id': '5a5513f1-43d9-4388-bd70-68f72bb28a3d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2919, 'output_tokens': 100, 'total_tokens': 3019, 'input_token_details': {'cache_read': 1756}, 'output_token_details': {'reasoning': 78}}),
#   ToolMessage(content='### Task 1: Calculating the total population of Ireland in 2002.\n\n**Code:**\n```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/B0205.csv")\n\n# Filter for total population in 2002\ntotal_population_2002 = df[(df["Age Last Birthday"] == "All ages") & \n                           (df["At Each Year of Age"] == "Population")]\n\n# Get the value for total population\npopulation_value = total_population_2002["value"].iloc[0]\n\nprint(f"The total population of Ireland in 2002 was: {population_value:,.0f}")\n\n```\n**Output:**\n```python\nThe total population of Ireland in 2002 was: 3,917,203\n\n```\n', name='provenance_tool', id='c0d57edb-4e4a-45ba-ac82-1e1d1c104d44', tool_call_id='5a5513f1-43d9-4388-bd70-68f72bb28a3d'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'provenance_tool', 'arguments': '{"table_id": "overall_analysis"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--557085bc-11e2-4ecc-8f59-7736c51b0010-0', tool_calls=[{'name': 'provenance_tool', 'args': {'table_id': 'overall_analysis'}, 'id': 'a99bbad5-78c5-4bc7-8341-9729bf73c75e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3183, 'output_tokens': 76, 'total_tokens': 3259, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 56}}),
#   ToolMessage(content='', name='provenance_tool', id='91801e97-7a42-4938-9be9-73b19b514502', tool_call_id='a99bbad5-78c5-4bc7-8341-9729bf73c75e'),
#   AIMessage(content='The code used for the analysis of population growth in Ireland is as follows:\n\n### For Table E3002 (Population 2011 to 2016)\n\n**Task 1: Extracting population for 2011**```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2011 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2011)]["value"].iloc[0]\n\nprint(f"Population in 2011: {population_2011}")\n\n```\n\n**Task 2: Extracting population for 2016**```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2016 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2016)]["value"].iloc[0]\n\nprint(f"Population in 2016: {population_2016}")\n\n```\n\n### For Table B0205 (Population 2002)\n\n**Task 1: Calculating the total population of Ireland in 2002.**```python\n\nimport pandas as pd\n\ndf = pd.read_csv("cache/B0205.csv")\n\n# Filter for total population in 2002\ntotal_population_2002 = df[(df["Age Last Birthday"] == "All ages") & \n                           (df["At Each Year of Age"] == "Population")]\n\n# Get the value for total population\npopulation_value = total_population_2002["value"].iloc[0]\n\nprint(f"The total population of Ireland in 2002 was: {population_value:,.0f}")\n\n```', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='e1e63b95-f530-4dc3-ad14-01299dce54a4')],
#  'question': 'please show me the code you used for your analysis?',
#  'iter': 4,
#  'relevant_tables_ids': [{'table_id': 'E3002',
#    'context': '**Table ID:** E3002\n- **CSV File Path**: cache/E3002.csv\n- **Table Shape**: (5508, 7)\n- **Table Info**:\n                     columns  dtypes nunique  nulls\n                   Statistic  object       1      0\n                         Sex  object       3      0\n           Age Last Birthday  object     >50      0\n                  CensusYear   int64       2      0\nAggregate Town or Rural Area  object       3      0\n         At Each Year of Age  object       3      0\n                       value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n              Statistic        Sex  Age Last Birthday  CensusYear Aggregate Town or Rural Area             At Each Year of Age     value\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State                      Population 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State Population at or under this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011                        State  Population at or over this age 4588252.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area                      Population 2846882.0\nPopulation 2011 to 2016 Both sexes           All ages        2011          Aggregate Town Area Population at or under this age 2846882.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area Population at or under this age 1527054.0\nPopulation 2011 to 2016     Female 100 years and over        2016          Aggregate Town Area  Population at or over this age     225.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area                      Population     147.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area Population at or under this age  880383.0\nPopulation 2011 to 2016     Female 100 years and over        2016         Aggregate Rural Area  Population at or over this age     147.0',
#    'analysis_plan': ["Filter the data to include rows where 'Statistic' is 'Population 2011 to 2016', 'Aggregate Town or Rural Area' is 'State', 'Age Last Birthday' is 'All ages', and 'At Each Year of Age' is 'Population'.",
#     "Select 'CensusYear' and 'value' columns to get the total population for the years 2011 and 2016."]},
#   {'table_id': 'B0205',
#    'context': '**Table ID:** B0205\n- **CSV File Path**: cache/B0205.csv\n- **Table Shape**: (612, 6)\n- **Table Info**:\n            columns  dtypes nunique  nulls\n          Statistic  object       1      0\n                Sex  object       3      0\n  Age Last Birthday  object     >50      0\nAt Each Year of Age  object       2      0\n         CensusYear   int64       1      0\n              value float64     >50      0\n- **Table Sample (first and last 5 rows)**:\n       Statistic        Sex  Age Last Birthday             At Each Year of Age  CensusYear     value\n2002  Population Both sexes           All ages                      Population        2002 3917203.0\n2002  Population Both sexes           All ages Population at or under this age        2002 3917203.0\n2002  Population Both sexes       Under 1 year                      Population        2002   54499.0\n2002  Population Both sexes       Under 1 year Population at or under this age        2002   54499.0\n2002  Population Both sexes             1 year                      Population        2002   55362.0\n2002  Population     Female           98 years Population at or under this age        2002 1970691.0\n2002  Population     Female           99 years                      Population        2002     140.0\n2002  Population     Female           99 years Population at or under this age        2002 1970831.0\n2002  Population     Female 100 years and over                      Population        2002     208.0\n2002  Population     Female 100 years and over Population at or under this age        2002 1971039.0',
#    'analysis_plan': ["Filter the data to include rows where 'Statistic' is '2002 Population', 'Age Last Birthday' is 'All ages', and 'At Each Year of Age' is 'Population'.",
#     "Select 'CensusYear' and 'value' columns to get the total population for the year 2002."]},
#   {'table_id': 'overall_analysis',
#    'context': '',
#    'analysis_plan': ['Combine the filtered data from E3002 and B0205.',
#     "Sort the combined data by 'CensusYear' in ascending order.",
#     'Calculate the population growth by finding the difference in population values between the earliest year (2002) and the latest year (2016) to show the overall growth over the last two decades.',
#     'Present the population figures for 2002, 2011, and 2016, and the calculated total population growth.']}],
#  'reports': {'E3002': [{'task': 'Extracting population for 2011',
#     'code': '\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2011 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2011)]["value"].iloc[0]\n\nprint(f"Population in 2011: {population_2011}")\n',
#     'result': 'Population in 2011: 4588252.0\n'},
#    {'task': 'Extracting population for 2016',
#     'code': '\nimport pandas as pd\n\ndf = pd.read_csv("cache/E3002.csv")\n\npopulation_2016 = df[(df["Statistic"] == "Population 2011 to 2016") & \n                     (df["Aggregate Town or Rural Area"] == "State") & \n                     (df["Age Last Birthday"] == "All ages") & \n                     (df["At Each Year of Age"] == "Population") & \n                     (df["CensusYear"] == 2016)]["value"].iloc[0]\n\nprint(f"Population in 2016: {population_2016}")\n',
#     'result': 'Population in 2016: 4761865.0\n'}],
#   'B0205': [{'task': 'Calculating the total population of Ireland in 2002.',
#     'code': '\nimport pandas as pd\n\ndf = pd.read_csv("cache/B0205.csv")\n\n# Filter for total population in 2002\ntotal_population_2002 = df[(df["Age Last Birthday"] == "All ages") & \n                           (df["At Each Year of Age"] == "Population")]\n\n# Get the value for total population\npopulation_value = total_population_2002["value"].iloc[0]\n\nprint(f"The total population of Ireland in 2002 was: {population_value:,.0f}")\n',
#     'result': 'The total population of Ireland in 2002 was: 3,917,203\n'}],
#   'overall_analysis': []}}

# %%
print(res_follow_up["messages"][-1].content)
# Out:
# The code used for the analysis of population growth in Ireland is as follows:
#
# ### For Table E3002 (Population 2011 to 2016)
#
# **Task 1: Extracting population for 2011**```python
#
# import pandas as pd
#
# df = pd.read_csv("cache/E3002.csv")
#
# population_2011 = df[(df["Statistic"] == "Population 2011 to 2016") &
#                      (df["Aggregate Town or Rural Area"] == "State") &
#                      (df["Age Last Birthday"] == "All ages") &
#                      (df["At Each Year of Age"] == "Population") &
#                      (df["CensusYear"] == 2011)]["value"].iloc[0]
#
# print(f"Population in 2011: {population_2011}")
#
# ```
#
# **Task 2: Extracting population for 2016**```python
#
# import pandas as pd
#
# df = pd.read_csv("cache/E3002.csv")
#
# population_2016 = df[(df["Statistic"] == "Population 2011 to 2016") &
#                      (df["Aggregate Town or Rural Area"] == "State") &
#                      (df["Age Last Birthday"] == "All ages") &
#                      (df["At Each Year of Age"] == "Population") &
#                      (df["CensusYear"] == 2016)]["value"].iloc[0]
#
# print(f"Population in 2016: {population_2016}")
#
# ```
#
# ### For Table B0205 (Population 2002)
#
# **Task 1: Calculating the total population of Ireland in 2002.**```python
#
# import pandas as pd
#
# df = pd.read_csv("cache/B0205.csv")
#
# # Filter for total population in 2002
# total_population_2002 = df[(df["Age Last Birthday"] == "All ages") &
#                            (df["At Each Year of Age"] == "Population")]
#
# # Get the value for total population
# population_value = total_population_2002["value"].iloc[0]
#
# print(f"The total population of Ireland in 2002 was: {population_value:,.0f}")
#
# ```
